# %% [markdown]
# # All exercises: Python Programming, SKEMA 2026
#
# Every exercise of labs 1, 2 and 3, plus the bonus ones, in a single page you can run
# in your browser.
#
# ---
#
# ## How to use this notebook
#
# 1. Menu **File > Save a copy in Drive**. You work on YOUR copy.
# 2. Run a cell: click inside it, then **Shift + Enter**.
# 3. Run the **Setup** cell below once per session, before exercises 7.0 and 7.1.
# 4. Sections are collapsible. Use the table of contents on the left to jump around.
#
# This notebook is a working surface, not your submission. Your graded work lives in
# your GitHub repository. When an exercise is finished, copy it into the matching
# `.py` file in `exercises/` and commit.
#
# The `../examples/` files quoted in the hints are in your repository, not here.
#
# ---
#
# ## The four steps, on every exercise
#
# 1. **Ask** the AI: describe what the code must do, what goes in, what comes out
# 2. **Read** it: write your own comment above each block. If you cannot, you have not understood it
# 3. **Adapt** it: the AI does not know your files. Connect its code to your data
# 4. **Check** it: test one case where you already know the answer
#
# A program that runs is not the same thing as a program that is right.
#
# ---
#
# ## What is graded, and what is not
#
# | | |
# |---|---|
# | In class | Done during the lab, with your teacher in the room |
# | At home | The improved version, done with an AI assistant |
# | Bonus | Optional. No slot, no assessment |
#
# Your commit history is how your teacher sees the work you did. One single commit the
# night before the deadline tells its own story.

# %% [markdown]
# ---
# # Setup
#
# Run this once per session. It creates the two data files that exercises 7.0 and 7.1
# need. In your repository these files are already there, a Colab session starts empty.

# %%
# Setup: creates the data files used by exercises 7.0 and 7.1

names = """ada LOVELACE
grace hopper

  alan TURING
katherine JOHNSON
margaret hamilton
  linus torvalds
GUIDO van rossum

barbara LISKOV
"""

with open("names.txt", "w", encoding="utf-8") as f:
    f.write(names)

with open("7.0_student_data.csv", "w", encoding="utf-8") as f:
    f.write("first_name;last_name;email;student_number\n")

print("names.txt and 7.0_student_data.csv are ready.")
print("Files you create here disappear when the session ends.")
print("To keep one: left panel, Files, right click the file, Download.")

# %% [markdown]
# ---
# # Lab 1: your first programs
#
# Three exercises in class, two at home. If you can finish these, the rest of the course is a variation on them.

# %% [markdown]
# ## Exercise 1.0 : Hello World
#
# *in class*
#
# **Goal**
#
# Write the simplest possible program, and prove your environment works.
#
# **In class**
#
# Print the text: Hello, World!
#
# **Improved version**
#
# Print the message five times, and add the iteration number to each line.
# Expected output:
# ```
# 1 Hello, World!
# 2 Hello, World!
# ... and so on
# ```
#
# **Hints**
#
# ```
# print() displays text. A for loop repeats work. range(5) counts to five.
# See ../examples/loops/for_loop.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Write your own comments as you go.
# ```

# %%
# TODO 1: print Hello, World!


# TODO 2 (improved version): print it five times, numbered

# %% [markdown]
# ## Exercise 2.0 : User input and string concatenation
#
# *in class*
#
# **Goal**
#
# Ask the user something, then use the answer.
#
# **In class**
#
# Ask for the user's name, then greet them by name.
#
# **Improved version**
#
# Ask for the name AND the age, then print a sentence containing both.
# Remember that input() gives you text, so the age must be converted
# before you can compute with it.
#
# **Hints**
#
# ```
# input("question ") displays the question and waits.
# int("30") turns text into a number.
# See ../examples/io/input_function.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check.
# ```

# %%
# TODO 1: ask for the name and greet the user


# TODO 2 (improved version): also ask for the age, and use it in a sentence

# %% [markdown]
# ## Exercise 3.0 : Basic arithmetic
#
# *in class*
#
# **Goal**
#
# Compute with numbers the user typed.
#
# **In class**
#
# Ask for two numbers, then display their sum.
#
# **Improved version**
#
# Display the four operations: sum, difference, product, division.
# Handle the case where the second number is zero, because dividing by
# zero stops the program.
#
# **Hints**
#
# ```
# float("3.5") converts text into a decimal number.
# Test the divisor BEFORE dividing.
# See ../examples/numbers/integers.py and ../examples/conditions/if_else.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Try it with 0 as the second number.
# ```

# %%
# TODO 1: ask for two numbers and display their sum


# TODO 2 (improved version): the four operations, with the division protected

# %% [markdown]
# ## Exercise 2.1 : String manipulation
#
# *at home*
#
# **Goal**
#
# Transform text, which is most of what a program does with real data.
#
# **In class**
#
# Join two strings, and repeat one of them several times.
#
# **Improved version**
#
# Ask the user for a sentence, then display it:
# - in upper case
# - in lower case
# - with the number of characters it contains
# - with the first and last word
#
# **Hints**
#
# ```
# "a" + "b" joins, "a" * 3 repeats.
# .upper() .lower() .strip() .split() are the methods you need.
# len() counts. A split gives a list, and [0] and [-1] are its ends.
# See ../examples/strings/string_methods.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Test with a sentence that has spaces at both ends.
# ```

# %%
# TODO 1: join two strings, and repeat one of them


# TODO 2 (improved version): transform a sentence given by the user

# %% [markdown]
# ## Exercise 3.1 : Odd or even
#
# *at home*
#
# **Goal**
#
# Use the remainder of a division to classify a number.
#
# **In class**
#
# Ask for a number and say whether it is odd or even.
#
# **Improved version**
#
# Do it for every number from 1 to 20, one line each.
#
# **Hints**
#
# ```
# number % 2 gives the remainder of the division by two.
# A remainder of 0 means the number is even.
# See ../examples/numbers/integers.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Check 0 and a negative number too.
# ```

# %%
# TODO 1: odd or even for one number given by the user


# TODO 2 (improved version): the same for the numbers 1 to 20

# %% [markdown]
# ---
# # Lab 2: collections and decisions
#
# Storing several values, reaching them, and making the program react to what it finds.

# %% [markdown]
# ## Exercise 4.0 : Lists
#
# *in class*
#
# **Goal**
#
# Store several values in one place and reach them.
#
# **In class**
#
# Build a list of three fruits, add a fourth, then display the second one
# and the whole list.
#
# **Improved version**
#
# Build a list of numbers, sort it, display the smallest, the largest and
# the average.
#
# **Hints**
#
# ```
# .append() adds, [1] reads the second item, .sort() reorders.
# min(), max(), sum() and len() do the rest.
# See ../examples/lists/list_methods.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Compute the average by hand once, and compare.
# ```

# %%
# TODO 1: create a list, add an item, display one item and the whole list


# TODO 2 (improved version): sort a list of numbers and describe it

# %% [markdown]
# ## Exercise 4.2 : Dictionaries
#
# *in class*
#
# **Goal**
#
# Store values you reach by name instead of by position.
#
# **In class**
#
# Build a dictionary describing a person with a name, an age and a city,
# then display each value.
#
# **Improved version**
#
# Add an occupation, update the age, remove the city, and display the
# dictionary after each change. Then loop over it to display every
# key and its value.
#
# **Hints**
#
# ```
# person["job"] = "teacher" adds a key.
# .pop("city") removes one. .items() gives keys and values together.
# See ../examples/dictionaries/access_elements.py and update_elements.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check.
# ```

# %%
# TODO 1: create the dictionary and display its values


# TODO 2 (improved version): add, update, remove, then loop over it

# %% [markdown]
# ## Exercise 5.0 : Conditions
#
# *in class*
#
# **Goal**
#
# Make the program react to what it is given.
#
# **In class**
#
# Ask for an age, then say whether the person is an adult or a minor.
#
# **Improved version**
#
# Give a different message for several age groups: child, teenager,
# adult, senior. Choose your own boundaries and state them in a comment.
#
# **Hints**
#
# ```
# if, elif, elif, else. The order matters: the first true test wins.
# Remember that input() gives text, so convert the age.
# See ../examples/conditions/if_else.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Test exactly on your boundary values.
# ```

# %%
# TODO 1: adult or minor


# TODO 2 (improved version): one message per age group

# %% [markdown]
# ## Exercise 4.1 : Reversing and sorting a list
#
# *at home*
#
# **Goal**
#
# Change the order of a list without losing the original.
#
# **In class**
#
# Create a list of numbers and display it in reverse order.
#
# **Improved version**
#
# Display, one after the other:
# - the original list
# - the same list reversed
# - the same list sorted, smallest first
# - the same list sorted, largest first
#
# The original list must still be intact at the end.
#
# **Hints**
#
# ```
# .reverse() and .sort() change the list itself.
# sorted() and list[::-1] return a new list and leave the original alone.
# That difference is the whole point of this exercise.
# See ../examples/lists/list_methods.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Print the original at the very end to prove it is intact.
# ```

# %%
# TODO 1: display a list in reverse order


# TODO 2 (improved version): the four views, with the original left untouched

# %% [markdown]
# ---
# # Lab 3: repetition, functions, files
#
# The densest lab. Every building block of the final project is here.

# %% [markdown]
# ## Exercise 5.1 : For loops
#
# *in class*
#
# **Goal**
#
# Repeat work once per item.
#
# **In class**
#
# Print five numbered lines using range().
#
# **Improved version**
#
# Loop over a list of names and greet each person by name, with their
# position in the list.
#
# **Hints**
#
# ```
# for value in range(5): repeats five times.
# for name in names: takes each item in turn.
# enumerate(names, start=1) gives the position as well.
# See ../examples/loops/for_loop.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check.
# ```

# %%
# TODO 1: five numbered lines


# TODO 2 (improved version): greet every name in a list, with its position

# %% [markdown]
# ## Exercise 5.2 : While loops
#
# *in class*
#
# **Goal**
#
# Repeat until something changes, when you do not know how many times.
#
# **In class**
#
# Count from 1 to 5 with a while loop.
#
# **Improved version**
#
# Ask the user, again and again, whether they want to continue.
# Stop when they answer no. Count how many times they said yes,
# and display that count at the end.
#
# **Hints**
#
# ```
# Something inside the loop must eventually make the test false,
# otherwise the program never stops.
# .strip().lower() on the answer avoids "Yes" and " yes " being rejected.
# See ../examples/loops/while_loop.py and early_exit.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Try answering with capitals and extra spaces.
# ```

# %%
# TODO 1: count from 1 to 5


# TODO 2 (improved version): keep asking until the user says no, and count the yeses

# %% [markdown]
# ## Exercise 6.0 : Functions
#
# *in class*
#
# **Goal**
#
# Give a name to a piece of work so you can reuse it.
#
# **In class**
#
# Write a function that prints a greeting, then call it.
#
# **Improved version**
#
# Write a function that takes two numbers, returns their sum, and does not
# print anything itself. Call it three times with different values and
# print the results.
#
# **Hints**
#
# ```
# def name(parameters): defines. name(values) calls.
# return sends a value back. print only displays.
# A function that computes should return, not print. That way you can reuse it.
# See ../examples/functions/define_and_call.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check.
# ```

# %%
# TODO 1: a function that prints a greeting


# TODO 2 (improved version): a function that RETURNS the sum of two numbers

# %% [markdown]
# ## Exercise 6.1 : Functions working together
#
# *in class*
#
# **Goal**
#
# Split a task into small functions, and have one coordinate the others.
#
# **In class**
#
# Write is_even(number) and is_zero(number), then a third function that
# uses both to describe a number.
#
# **Improved version**
#
# Add is_positive(number) and is_negative(number). The describing function
# must say both things: whether the number is positive, negative or zero,
# AND whether it is odd or even. Test it on 0, on a positive number and
# on a negative one.
#
# **Hints**
#
# ```
# A function can call another function.
# One function, one job. The name should say the job.
# Deal with zero first, it is the special case.
# See ../examples/functions/functions_calling_functions.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Zero is the case people forget.
# ```

# %%
# TODO 1: is_even, is_zero, and a function that uses them


# TODO 2 (improved version): add is_positive and is_negative, and combine everything

# %% [markdown]
# ## Exercise 7.0 : Standard input and writing a CSV
#
# *in class*
#
# **Goal**
#
# Collect information from the user and save it to a file.
#
# **In class**
#
# Ask for a first name, a last name, an email and a student number,
# then write them to a CSV file.
#
# **Improved version**
#
# Add the data to the file instead of replacing it, so several students
# can be recorded one after the other. Check the input before saving:
# - the names must not be empty
# - the email must contain an @
# - the student number must be digits only
#
# Ask again when a value is not acceptable.
#
# **Expected file**
#
# ```
# See 7.0_student_data.csv for the columns your file must have.
# ```
#
# **Hints**
#
# ```
# open(path, "w") replaces the file, open(path, "a") adds to it.
# csv.writer() writes rows. Write the header only when the file is new.
# os.path.exists(path) tells you whether the file is already there.
# See ../examples/files/write_a_csv.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Open the file afterwards and look at it.
# ```

# %%
# TODO 1: collect the four values and write them to a CSV file


# TODO 2 (improved version): append instead of replace, and validate every value

# %% [markdown]
# ## Exercise 7.1 : Reading and processing a file
#
# *at home*
#
# **Goal**
#
# Read a file, clean what is inside, and write the result somewhere else.
# This is the direct rehearsal for the final project.
#
# **In class**
#
# Read names.txt, display every name it contains.
#
# **Improved version**
#
# Read names.txt, then:
# - remove the spaces and line breaks around each name
# - capitalise them properly, so "ada LOVELACE" becomes "Ada Lovelace"
# - sort them by LAST name, not by first name
# - write the result to sorted_names.txt
#
# Ignore empty lines instead of crashing on them.
#
# **Hints**
#
# ```
# with open(path) as file: opens and closes the file for you.
# .readlines() gives a list of lines, each ending with \n.
# .strip() removes it. .title() fixes the capitals. .split() separates the words.
# sorted(names, key=...) sorts on something other than the whole string.
# See ../examples/files/read_a_csv.py for the opening pattern.
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Open sorted_names.txt and verify the order yourself.
# ```

# %%
# TODO 1: read names.txt and display every name


# TODO 2 (improved version): clean, sort by last name, and write the result to a file

# %% [markdown]
# ---
# # Bonus: not covered in class, not graded
#
# Open these if you finished early or if you want to go further. Nothing here is assessed.

# %% [markdown]
# ## Exercise 8.0 : Operators (bonus, not graded)
#
# *bonus*
#
# **Goal**
#
# Get comfortable with assignment, comparison and logical operators.
#
# **Task**
#
# Take two numbers. Display the result of every comparison between them,
# then combine those results with and, or and not, and display those too.
#
# **Improved version**
#
# Ask the user for the two numbers, and present the results as a readable
# table rather than a list of raw True and False.
#
# **Hints**
#
# ```
# ==, !=, <, >, <=, >= produce True or False.
# and, or, not combine them.
# f"{label:<20} {value}" lines up a column.
# See ../examples/operators/comparison.py and logical.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check.
# ```

# %%
# TODO: compare two numbers, then combine the results

# %% [markdown]
# ## Exercise 8.1 : Bitwise operators (bonus, not graded)
#
# *bonus*
#
# **Goal**
#
# Understand how permissions are stored as bits, the way Linux and macOS do it.
#
# **Task**
#
# Define READ, WRITE and EXECUTE as 4, 2 and 1. Combine read and write into
# one value. Test whether that value includes execute. Then add execute,
# and remove write.
#
# **Improved version**
#
# Write a function that turns a permission value into a readable string,
# such as "rw-" or "r-x".
#
# **Hints**
#
# ```
# | adds a flag, & tests one, ~ inverts. bin(value) shows the bits.
# See ../examples/operators/bitwise.py
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check.
# ```

# %%
# TODO: combine, test, add and remove permissions

# %% [markdown]
# ## Exercise 9.0 : Handling errors
#
# *bonus*
#
# **Goal**
#
# Keep the program alive when something goes wrong. You will need this
# in the final project, where two campaigns have zero conversions.
#
# **Task**
#
# Ask the user for a number and display it. If the user types something
# that is not a number, say so instead of crashing.
#
# **Improved version**
#
# Also divide 10 by that number, and handle two different problems
# separately:
# - ValueError, when the text is not a number
# - ZeroDivisionError, when the number is zero
#
# Then keep asking until the user gives an acceptable value.
#
# **Hints**
#
# ```
# try: the risky code
# except ValueError: what to do in that case
# except ZeroDivisionError: what to do in that other case
# Catching the specific error is better than catching everything.
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Test with "abc", with 0, and with 5.
# ```

# %%
# TODO 1: read a number, and survive a wrong entry


# TODO 2 (improved version): divide, handle both errors, keep asking until it works

# %% [markdown]
# ## Exercise 10.0 : Regular expressions (bonus, not graded)
#
# *bonus*
#
# **Goal**
#
# Check the shape of a piece of text: is this really an email address?
#
# **Task**
#
# Search for a word inside a sentence using the re module, and say whether
# it was found.
#
# **Improved version**
#
# Write three validation functions:
# - a name contains only letters and spaces
# - an email looks like something@something.something
# - a student number is exactly eight digits
#
# Ask the user for the three values, validate each one, and only save them
# to a CSV file when all three are acceptable.
#
# **Hints**
#
# ```
# import re, then re.search(pattern, text) or re.match(pattern, text).
# A pattern is a small language of its own. Ask the AI to explain the
# pattern it gives you, line by line, before you use it.
# ```
#
# **Four steps**
#
# ```
# Ask, read, adapt, check. Test with a deliberately wrong email.
# ```

# %%
# TODO: search for a word, then validate three kinds of value

# %% [markdown]
# ---
# # Finished?
#
# Next steps, in this order:
#
# 1. Copy each finished exercise into its `.py` file in `exercises/`, in your repository
# 2. Commit and sync
# 3. Open `final-project/README.md`, the Campaign Audit Quiz is the graded work
#
# Stuck on something for more than fifteen minutes: ask. In the chat during a session,
# or to your lab teacher. Being stuck is normal, staying stuck is a choice.
